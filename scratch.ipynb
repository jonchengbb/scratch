# %%
import boto3
import pyarrow.parquet as pq

# %%
URI = "s3://bbio-data-platform/prod/glue/target_intelligence/open_targets_evidence/part-00001-tid-6793543178480712938-a8559181-3f54-432c-9901-c16dc93f4338-412-1-c000.snappy.parquet"

# %%
schema=pq.read_schema(URI)

# %%
"run_date" in schema.names
# Out:
# False

# %%
# Initialize Glue client
glue_client = boto3.client('glue')

# Get table description
try:
    response = glue_client.get_table(
        DatabaseName='target_intelligence',  # replace with your database name
        Name='open_targets_evidence'        # table name from your URI
    )
    
    # Print table details
    table_info = response['Table']
    # print(f"Table Name: {table_info['Name']}")
    # print(f"Database: {table_info['DatabaseName']}")
    print(f"Description: {table_info.get('Description', 'No description available')}")
    # print("\nColumns:")
    # for col in table_info['StorageDescriptor']['Columns']:
    #     print(f"- {col['Name']}: {col['Type']}")
        
except glue_client.exceptions.EntityNotFoundException:
    print("Table not found")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Description: No description available

# %%
print(f"Partitioned: {'PartitionKeys' in table_info}")
# Out:
# Partitioned: True

# %%
table_info
# Out:
# {'Name': 'open_targets_evidence',
#  'DatabaseName': 'target_intelligence',
#  'Owner': 'root',
#  'CreateTime': datetime.datetime(2024, 5, 30, 13, 7, 19, tzinfo=tzlocal()),
#  'UpdateTime': datetime.datetime(2024, 5, 30, 13, 7, 19, tzinfo=tzlocal()),
#  'LastAccessTime': datetime.datetime(1969, 12, 31, 16, 0, tzinfo=tzlocal()),
#  'Retention': 0,
#  'StorageDescriptor': {'Columns': [{'Name': 'datasource_id', 'Type': 'string'},
#    {'Name': 'target_id', 'Type': 'string'},
#    {'Name': 'ancestry', 'Type': 'string'},
#    {'Name': 'ancestry_id', 'Type': 'string'},
#    {'Name': 'beta', 'Type': 'double'},
#    {'Name': 'beta_confidence_interval_lower', 'Type': 'double'},
#    {'Name': 'beta_confidence_interval_upper', 'Type': 'double'},
#    {'Name': 'biological_model_allelic_composition', 'Type': 'string'},
#    {'Name': 'biological_model_genetic_background', 'Type': 'string'},
#    {'Name': 'biological_model_id', 'Type': 'string'},
#    {'Name': 'biomarker_name', 'Type': 'string'},
#    {'Name': 'cell_type', 'Type': 'string'},
#    {'Name': 'clinical_phase', 'Type': 'double'},
#    {'Name': 'clinical_status', 'Type': 'string'},
#    {'Name': 'cohort_description', 'Type': 'string'},
#    {'Name': 'cohort_id', 'Type': 'string'},
#    {'Name': 'cohort_short_name', 'Type': 'string'},
#    {'Name': 'confidence', 'Type': 'string'},
#    {'Name': 'contrast', 'Type': 'string'},
#    {'Name': 'crispr_screen_library', 'Type': 'string'},
#    {'Name': 'datatype_id', 'Type': 'string'},
#    {'Name': 'disease_from_source', 'Type': 'string'},
#    {'Name': 'disease_from_source_id', 'Type': 'string'},
#    {'Name': 'disease_from_source_mapped_id', 'Type': 'string'},
#    {'Name': 'drug_from_source', 'Type': 'string'},
#    {'Name': 'drug_id', 'Type': 'string'},
#    {'Name': 'drug_response', 'Type': 'string'},
#    {'Name': 'genetic_background', 'Type': 'string'},
#    {'Name': 'log2_fold_change_percentile_rank', 'Type': 'bigint'},
#    {'Name': 'log2_fold_change_value', 'Type': 'double'},
#    {'Name': 'odds_ratio', 'Type': 'double'},
#    {'Name': 'odds_ratio_confidence_interval_lower', 'Type': 'double'},
#    {'Name': 'odds_ratio_confidence_interval_upper', 'Type': 'double'},
#    {'Name': 'p_value_exponent', 'Type': 'bigint'},
#    {'Name': 'p_value_mantissa', 'Type': 'double'},
#    {'Name': 'project_id', 'Type': 'string'},
#    {'Name': 'publication_first_author', 'Type': 'string'},
#    {'Name': 'publication_year', 'Type': 'bigint'},
#    {'Name': 'reaction_id', 'Type': 'string'},
#    {'Name': 'reaction_name', 'Type': 'string'},
#    {'Name': 'release_date', 'Type': 'string'},
#    {'Name': 'resource_score', 'Type': 'double'},
#    {'Name': 'statistical_method', 'Type': 'string'},
#    {'Name': 'statistical_method_overview', 'Type': 'string'},
#    {'Name': 'statistical_test_tail', 'Type': 'string'},
#    {'Name': 'study_cases', 'Type': 'bigint'},
#    {'Name': 'study_cases_with_qualifying_variants', 'Type': 'bigint'},
#    {'Name': 'study_id', 'Type': 'string'},
#    {'Name': 'study_overview', 'Type': 'string'},
#    {'Name': 'study_sample_size', 'Type': 'bigint'},
#    {'Name': 'study_start_date', 'Type': 'string'},
#    {'Name': 'study_stop_reason', 'Type': 'string'},
#    {'Name': 'target_from_source', 'Type': 'string'},
#    {'Name': 'target_from_source_id', 'Type': 'string'},
#    {'Name': 'target_in_model', 'Type': 'string'},
#    {'Name': 'target_in_model_ensembl_id', 'Type': 'string'},
#    {'Name': 'target_in_model_mgi_id', 'Type': 'string'},
#    {'Name': 'target_modulation', 'Type': 'string'},
#    {'Name': 'variant_functional_consequence_from_qtl_id', 'Type': 'string'},
#    {'Name': 'variant_functional_consequence_id', 'Type': 'string'},
#    {'Name': 'variant_hgvs_id', 'Type': 'string'},
#    {'Name': 'variant_id', 'Type': 'string'},
#    {'Name': 'variant_rs_id', 'Type': 'string'},
#    {'Name': 'disease_id', 'Type': 'string'},
#    {'Name': 'id', 'Type': 'string'},
#    {'Name': 'score', 'Type': 'double'},
#    {'Name': 'variant_effect', 'Type': 'string'},
#    {'Name': 'direction_on_trait', 'Type': 'string'},
#    {'Name': 'source_id', 'Type': 'string'}],
#   'Location': 's3://bbio-data-platform/prod/glue/target_intelligence/open_targets_evidence',
#   'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#   'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#   'Compressed': False,
#   'NumberOfBuckets': -1,
#   'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#    'Parameters': {'serialization.format': '1',
#     'path': 's3://bbio-data-platform/prod/glue/target_intelligence/open_targets_evidence'}},
#   'BucketColumns': [],
#   'SortColumns': [],
#   'Parameters': {},
#   'SkewedInfo': {'SkewedColumnNames': [],
#    'SkewedColumnValues': [],
#    'SkewedColumnValueLocationMaps': {}},
#   'StoredAsSubDirectories': False},
#  'PartitionKeys': [],
#  'TableType': 'MANAGED_TABLE',
#  'Parameters': {'transient_lastDdlTime': '1717099639',
#   'spark.sql.sources.schema.part.1': 'ble":true,"metadata":{}},{"name":"target_from_source_id","type":"string","nullable":true,"metadata":{}},{"name":"target_in_model","type":"string","nullable":true,"metadata":{}},{"name":"target_in_model_ensembl_id","type":"string","nullable":true,"metadata":{}},{"name":"target_in_model_mgi_id","type":"string","nullable":true,"metadata":{}},{"name":"target_modulation","type":"string","nullable":true,"metadata":{}},{"name":"variant_functional_consequence_from_qtl_id","type":"string","nullable":true,"metadata":{}},{"name":"variant_functional_consequence_id","type":"string","nullable":true,"metadata":{}},{"name":"variant_hgvs_id","type":"string","nullable":true,"metadata":{}},{"name":"variant_id","type":"string","nullable":true,"metadata":{}},{"name":"variant_rs_id","type":"string","nullable":true,"metadata":{}},{"name":"disease_id","type":"string","nullable":true,"metadata":{}},{"name":"id","type":"string","nullable":true,"metadata":{}},{"name":"score","type":"double","nullable":true,"metadata":{}},{"name":"variant_effect","type":"string","nullable":true,"metadata":{}},{"name":"direction_on_trait","type":"string","nullable":true,"metadata":{}},{"name":"source_id","type":"string","nullable":true,"metadata":{}}]}',
#   'spark.sql.sources.schema.numParts': '2',
#   'spark.sql.sources.provider': 'parquet',
#   'spark.sql.sources.schema.part.0': '{"type":"struct","fields":[{"name":"datasource_id","type":"string","nullable":true,"metadata":{}},{"name":"target_id","type":"string","nullable":true,"metadata":{}},{"name":"ancestry","type":"string","nullable":true,"metadata":{}},{"name":"ancestry_id","type":"string","nullable":true,"metadata":{}},{"name":"beta","type":"double","nullable":true,"metadata":{}},{"name":"beta_confidence_interval_lower","type":"double","nullable":true,"metadata":{}},{"name":"beta_confidence_interval_upper","type":"double","nullable":true,"metadata":{}},{"name":"biological_model_allelic_composition","type":"string","nullable":true,"metadata":{}},{"name":"biological_model_genetic_background","type":"string","nullable":true,"metadata":{}},{"name":"biological_model_id","type":"string","nullable":true,"metadata":{}},{"name":"biomarker_name","type":"string","nullable":true,"metadata":{}},{"name":"cell_type","type":"string","nullable":true,"metadata":{}},{"name":"clinical_phase","type":"double","nullable":true,"metadata":{}},{"name":"clinical_status","type":"string","nullable":true,"metadata":{}},{"name":"cohort_description","type":"string","nullable":true,"metadata":{}},{"name":"cohort_id","type":"string","nullable":true,"metadata":{}},{"name":"cohort_short_name","type":"string","nullable":true,"metadata":{}},{"name":"confidence","type":"string","nullable":true,"metadata":{}},{"name":"contrast","type":"string","nullable":true,"metadata":{}},{"name":"crispr_screen_library","type":"string","nullable":true,"metadata":{}},{"name":"datatype_id","type":"string","nullable":true,"metadata":{}},{"name":"disease_from_source","type":"string","nullable":true,"metadata":{}},{"name":"disease_from_source_id","type":"string","nullable":true,"metadata":{}},{"name":"disease_from_source_mapped_id","type":"string","nullable":true,"metadata":{}},{"name":"drug_from_source","type":"string","nullable":true,"metadata":{}},{"name":"drug_id","type":"string","nullable":true,"metadata":{}},{"name":"drug_response","type":"string","nullable":true,"metadata":{}},{"name":"genetic_background","type":"string","nullable":true,"metadata":{}},{"name":"log2_fold_change_percentile_rank","type":"long","nullable":true,"metadata":{}},{"name":"log2_fold_change_value","type":"double","nullable":true,"metadata":{}},{"name":"odds_ratio","type":"double","nullable":true,"metadata":{}},{"name":"odds_ratio_confidence_interval_lower","type":"double","nullable":true,"metadata":{}},{"name":"odds_ratio_confidence_interval_upper","type":"double","nullable":true,"metadata":{}},{"name":"p_value_exponent","type":"long","nullable":true,"metadata":{}},{"name":"p_value_mantissa","type":"double","nullable":true,"metadata":{}},{"name":"project_id","type":"string","nullable":true,"metadata":{}},{"name":"publication_first_author","type":"string","nullable":true,"metadata":{}},{"name":"publication_year","type":"long","nullable":true,"metadata":{}},{"name":"reaction_id","type":"string","nullable":true,"metadata":{}},{"name":"reaction_name","type":"string","nullable":true,"metadata":{}},{"name":"release_date","type":"string","nullable":true,"metadata":{}},{"name":"resource_score","type":"double","nullable":true,"metadata":{}},{"name":"statistical_method","type":"string","nullable":true,"metadata":{}},{"name":"statistical_method_overview","type":"string","nullable":true,"metadata":{}},{"name":"statistical_test_tail","type":"string","nullable":true,"metadata":{}},{"name":"study_cases","type":"long","nullable":true,"metadata":{}},{"name":"study_cases_with_qualifying_variants","type":"long","nullable":true,"metadata":{}},{"name":"study_id","type":"string","nullable":true,"metadata":{}},{"name":"study_overview","type":"string","nullable":true,"metadata":{}},{"name":"study_sample_size","type":"long","nullable":true,"metadata":{}},{"name":"study_start_date","type":"string","nullable":true,"metadata":{}},{"name":"study_stop_reason","type":"string","nullable":true,"metadata":{}},{"name":"targ ...
#   'spark.sql.create.version': '3.3.2'},
#  'CreatedBy': 'arn:aws:sts::821774515222:assumed-role/uk-biobank/i-0ca755843fd10bccb',
#  'IsRegisteredWithLakeFormation': False,
#  'CatalogId': '821774515222',
#  'VersionId': '0',
#  'IsMultiDialectView': False}

# %%
## Explore s3 buckets

s3_client = boto3.client('s3')
response = s3_client.list_buckets()

# Print bucket names
print("Available buckets:")
for bucket in response['Buckets']:
    print(f"- {bucket['Name']}")
# Out:
# Available buckets:
# - bbio-admera-data-transfer
# - bbio-adpkd-ncbi-data-delivery
# - bbio-compgen-infra
# - bbio-data-platform
# - bbio-databricks-npv
# - bbio-databricks-uc-metastore
# - bbio-databricks-workspace-lambdazipsbucket-1hwnnj0y8rlon
# - bbio-dls-data-transfer
# - bbio-functional-genomics
# - bbio-igv-app
# - bbio-igv-app2
# - bbio-nashbio-data
# - bbio-nextflow
# - bbio-nextflow-bbgt-aav-ngs-long-read-seq
# - bbio-nextflow-bbgt-capsid-evolution
# - bbio-pacbio-data-transfer
# - bbio-pacbio-smrtlink-data
# - bbio-pkd2-taiwan
# - bbio-workflow-results
# - bbiodbricks
# - core-metaflow-s3-v1
# - databricks-ukbiobank
# - metaflows35ay3bs8e

# %%
paginator = s3_client.get_paginator('list_objects_v2')

# %%
paginator

# %%
def list_dirs(bucket_name, prefix=''):
    """List all 'directories' in the bucket under specified prefix"""
    s3_client = boto3.client('s3')
    paginator = s3_client.get_paginator('list_objects_v2')
    
    # Use delimiter to emulate directory structure
    pages = paginator.paginate(
        Bucket=bucket_name,
        Prefix=prefix,
        Delimiter='/'
    )
    
    print(f"\nDirectories in {bucket_name}/{prefix}:")
    print("-" * 50)
    
    for page in pages:
        # Common prefixes are the "directories"
        for prefix in page.get('CommonPrefixes', []):
            print(f"└── {prefix['Prefix']}")

# Example usage - list top-level "directories"
list_dirs('bbio-data-platform')

# To go deeper into a specific path:
list_dirs('bbio-data-platform', 'dev/')
# Out:
# Directories in bbio-data-platform/:
# --------------------------------------------------
# └── dev/
# └── prod/
# └── raw/
# └── tmp/
#
# Directories in bbio-data-platform/dev/:
# --------------------------------------------------
# └── dev/airtable_archive/
# └── dev/alpha_missense/
# └── dev/athena/
# └── dev/bbio-gt/
# └── dev/citeline_trials_data/
# └── dev/data_driven_target_disease_prioritization/
# └── dev/dls_processed/
# └── dev/edgar/
# └── dev/evidgen/
# └── dev/gene_id_mapping/
# └── dev/genoox/
# └── dev/geuvadis/
# └── dev/global_data/
# └── dev/gtex/
# └── dev/human_genetics_dashboard/
# └── dev/incidence_estimator/
# └── dev/k8s_mnt/
# └── dev/knowledge_graphs/
# └── dev/manual_mappings/
# └── dev/mesh_terms/
# └── dev/nf-core--rnaseq/
# └── dev/onc_dashboard_data/
# └── dev/onc_main_data_repo/
# └── dev/open-targets-analysis/
# └── dev/orphanet/
# └── dev/pacbio-smrtlink-data-processed/
# └── dev/pops_features/
# └── dev/reactome_database/
# └── dev/rna_seq/
# └── dev/scrnaseq/
# └── dev/summary-statistics/
# └── dev/target_id/
# └── dev/users/
# └── dev/validation/

# %%
# create personal dev dir

def create_dev_directory(bucket_name, dev_path):
    """
    Create a development directory in S3
    Note: S3 doesn't actually create directories, but creates a zero-byte object with 
    a trailing slash to simulate a directory
    """
    s3_client = boto3.client('s3')
    
    # Ensure path ends with trailing slash
    if not dev_path.endswith('/'):
        dev_path += '/'
        
    try:
        # Create empty object with trailing slash to simulate directory
        s3_client.put_object(
            Bucket=bucket_name,
            Key=dev_path,
            Body=''
        )
        print(f"Created directory: s3://{bucket_name}/{dev_path}")
        
        # Verify it exists by listing it
        list_dirs(bucket_name, 'dev/')
        
    except Exception as e:
        print(f"Error creating directory: {str(e)}")

# Create your dev directory
create_dev_directory('bbio-data-platform', 'dev/jcheng')
# Out:
# Created directory: s3://bbio-data-platform/dev/jcheng/
#
# Directories in bbio-data-platform/dev/:
# --------------------------------------------------
# └── dev/airtable_archive/
# └── dev/alpha_missense/
# └── dev/athena/
# └── dev/bbio-gt/
# └── dev/citeline_trials_data/
# └── dev/data_driven_target_disease_prioritization/
# └── dev/dls_processed/
# └── dev/edgar/
# └── dev/evidgen/
# └── dev/gene_id_mapping/
# └── dev/genoox/
# └── dev/geuvadis/
# └── dev/global_data/
# └── dev/gtex/
# └── dev/human_genetics_dashboard/
# └── dev/incidence_estimator/
# └── dev/jcheng/
# └── dev/k8s_mnt/
# └── dev/knowledge_graphs/
# └── dev/manual_mappings/
# └── dev/mesh_terms/
# └── dev/nf-core--rnaseq/
# └── dev/onc_dashboard_data/
# └── dev/onc_main_data_repo/
# └── dev/open-targets-analysis/
# └── dev/orphanet/
# └── dev/pacbio-smrtlink-data-processed/
# └── dev/pops_features/
# └── dev/reactome_database/
# └── dev/rna_seq/
# └── dev/scrnaseq/
# └── dev/summary-statistics/
# └── dev/target_id/
# └── dev/users/
# └── dev/validation/

# %%
# Create organized subdirectories for different purposes
sandbox_dirs = [
    'dev/jcheng/tables/',           # For table development
    'dev/jcheng/temp/',            # For temporary data
    'dev/jcheng/experiments/',     # For experimental features
    'dev/jcheng/test_data/'       # For test datasets
]

for dir_path in sandbox_dirs:
    create_dev_directory('bbio-data-platform', dir_path)
# Out:
# Created directory: s3://bbio-data-platform/dev/jcheng/tables/
#
# Directories in bbio-data-platform/dev/:
# --------------------------------------------------
# └── dev/airtable_archive/
# └── dev/alpha_missense/
# └── dev/athena/
# └── dev/bbio-gt/
# └── dev/citeline_trials_data/
# └── dev/data_driven_target_disease_prioritization/
# └── dev/dls_processed/
# └── dev/edgar/
# └── dev/evidgen/
# └── dev/gene_id_mapping/
# └── dev/genoox/
# └── dev/geuvadis/
# └── dev/global_data/
# └── dev/gtex/
# └── dev/human_genetics_dashboard/
# └── dev/incidence_estimator/
# └── dev/jcheng/
# └── dev/k8s_mnt/
# └── dev/knowledge_graphs/
# └── dev/manual_mappings/
# └── dev/mesh_terms/
# └── dev/nf-core--rnaseq/
# └── dev/onc_dashboard_data/
# └── dev/onc_main_data_repo/
# └── dev/open-targets-analysis/
# └── dev/orphanet/
# └── dev/pacbio-smrtlink-data-processed/
# └── dev/pops_features/
# └── dev/reactome_database/
# └── dev/rna_seq/
# └── dev/scrnaseq/
# └── dev/summary-statistics/
# └── dev/target_id/
# └── dev/users/
# └── dev/validation/
# Created directory: s3://bbio-data-platform/dev/jcheng/temp/
#
# Directories in bbio-data-platform/dev/:
# --------------------------------------------------
# └── dev/airtable_archive/
# └── dev/alpha_missense/
# └── dev/athena/
# └── dev/bbio-gt/
# └── dev/citeline_trials_data/
# └── dev/data_driven_target_disease_prioritization/
# └── dev/dls_processed/
# └── dev/edgar/
# └── dev/evidgen/
# └── dev/gene_id_mapping/
# └── dev/genoox/
# └── dev/geuvadis/
# └── dev/global_data/
# └── dev/gtex/
# └── dev/human_genetics_dashboard/
# └── dev/incidence_estimator/
# └── dev/jcheng/
# └── dev/k8s_mnt/
# └── dev/knowledge_graphs/
# └── dev/manual_mappings/
# └── dev/mesh_terms/
# └── dev/nf-core--rnaseq/
# └── dev/onc_dashboard_data/
# └── dev/onc_main_data_repo/
# └── dev/open-targets-analysis/
# └── dev/orphanet/
# └── dev/pacbio-smrtlink-data-processed/
# └── dev/pops_features/
# └── dev/reactome_database/
# └── dev/rna_seq/
# └── dev/scrnaseq/
# └── dev/summary-statistics/
# └── dev/target_id/
# └── dev/users/
# └── dev/validation/
# Created directory: s3://bbio-data-platform/dev/jcheng/experiments/
#
# Directories in bbio-data-platform/dev/:
# --------------------------------------------------
# └── dev/airtable_archive/
# └── dev/alpha_missense/
# └── dev/athena/
# └── dev/bbio-gt/
# └── dev/citeline_trials_data/
# └── dev/data_driven_target_disease_prioritization/
# └── dev/dls_processed/
# └── dev/edgar/
# └── dev/evidgen/
# └── dev/gene_id_mapping/
# └── dev/genoox/
# └── dev/geuvadis/
# └── dev/global_data/
# └── dev/gtex/
# └── dev/human_genetics_dashboard/
# └── dev/incidence_estimator/
# └── dev/jcheng/
# └── dev/k8s_mnt/
# └── dev/knowledge_graphs/
# └── dev/manual_mappings/
# └── dev/mesh_terms/
# └── dev/nf-core--rnaseq/
# └── dev/onc_dashboard_data/
# └── dev/onc_main_data_repo/
# └── dev/open-targets-analysis/
# └── dev/orphanet/
# └── dev/pacbio-smrtlink-data-processed/
# └── dev/pops_features/
# └── dev/reactome_database/
# └── dev/rna_seq/
# └── dev/scrnaseq/
# └── dev/summary-statistics/
# └── dev/target_id/
# └── dev/users/
# └── dev/validation/
# Created directory: s3://bbio-data-platform/dev/jcheng/test_data/
#
# Directories in bbio-data-platform/dev/:
# --------------------------------------------------
# └── dev/airtable_archive/
# └── dev/alpha_missense/
# └── dev/athena/
# └── dev/bbio-gt/
# └── dev/citeline_trials_data/
# └── dev/data_driven_target_disease_prioritization/
# └── dev/dls_processed/
# └── dev/edgar/
# └── dev/evidgen/
# └── dev/gene_id_mapping/
# └── dev/genoox/
# └── dev/geuvadis/
# └── dev/global_data/
# └── dev/gtex/
# └── dev/human_genetics_dashboard/
# └── dev/incidence_estimator/
# └── dev/jcheng/
# └── dev/k8s_mnt/
# └── dev/knowledge_graphs/
# └── dev/manual_mappings/
# └── dev/mesh_terms/
# └── dev/nf-core--rnaseq/
# └── dev/onc_dashboard_data/
# └── dev/onc_main_data_repo/
# └── dev/open-targets-analysis/
# └── dev/orphanet/
# └── dev/pacbio-smrtlink-data-processed/
# └── dev/pops_features/
# └── dev/reactome_database/
# └── dev/rna_seq/
# └── dev/scrnaseq/
# └── dev/summary-statistics/
# └── dev/target_id/
# └── dev/users/
# └── dev/validation/

# %%
# Example: Writing a test table to your sandbox
import pandas as pd

# Create sample data
test_df = pd.DataFrame({
    'id': range(1, 5),
    'value': ['a', 'b', 'c', 'd']
})

# Save to your sandbox (parquet format recommended for AWS)
output_path = 's3://bbio-data-platform/dev/jcheng/tables/test_table.parquet'
test_df.to_parquet(output_path)
